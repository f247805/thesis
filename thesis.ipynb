# %% [markdown]
# <a href="https://colab.research.google.com/github/f247805/thesis/blob/main/thesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Feb 26 10:35:46 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/ThanosDiam/ABSA-Analysis-with-Explainability-Methods.git
# %cd ABSA-Analysis-with-Explainability-Methods
# Out:
# Cloning into 'ABSA-Analysis-with-Explainability-Methods'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 114 (delta 54), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (114/114), 1.13 MiB | 3.12 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# /content/ABSA-Analysis-with-Explainability-Methods/ABSA-Analysis-with-Explainability-Methods/ABSA-Analysis-with-Explainability-Methods

# %%
# !pip install transformers torch datasets lime shap captum
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.5 MB/s eta 0:00:00
# ...

# %%
import os
print(os.listdir())
# Out:
# ['Datasets', 'ATTENTION_WEIGHTS.py', 'SHAP.py', 'LIME.py', '.git', 'INTEGRATED_GRADIENTS.py', 'GRAD-CAM.py', 'LLM_CODE.py', 'TRAIN_LSTM.py', 'README.md', 'FINE_TUNE.py', 'Images', 'USE_THE_SAVED_FINE_TUNED_MODEL_CODE.py', 'TRAIN_RNN.py', 'TRAIN_BI-LSTM.py']

# %%
# %cd /content/ABSA-Analysis-with-Explainability-Methods
# Out:
# /content/ABSA-Analysis-with-Explainability-Methods

# %%
# !pip install jsonlines

# %%
# !python FINE_TUNE.py
# Out:
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 200kB/s]
# config.json: 100% 481/481 [00:00<00:00, 3.84MB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 11.4MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 3.13MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 6.18MB/s]
# 2025-02-26 13:10:37.725700: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740575437.743137    8966 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740575437.748671    8966 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !ls -lt
# Out:
# total 112
# drwxr-xr-x 2 root root  4096 Feb 26 13:46 tokenizer_roberta-base_lr_3e-6_bs_64_epoch_15_plots
# drwxr-xr-x 2 root root  4096 Feb 26 13:46 FINE_TUNED_MODEL_roberta-base_model_lr_3e-6_bs_64_epoch_15_plots
# drwxr-xr-x 6 root root  4096 Feb 26 13:09 ABSA-Analysis-with-Explainability-Methods
# -rw-r--r-- 1 root root 11768 Feb 26 13:08 FINE_TUNE.py
# -rw-r--r-- 1 root root  2992 Feb 26 12:37 LIME.py
# -rw-r--r-- 1 root root  6305 Feb 26 12:37 LLM_CODE.py
# -rw-r--r-- 1 root root  7223 Feb 26 12:37 README.md
# -rw-r--r-- 1 root root  1795 Feb 26 12:37 SHAP.py
# -rw-r--r-- 1 root root  9018 Feb 26 12:37 TRAIN_BI-LSTM.py
# -rw-r--r-- 1 root root  9034 Feb 26 12:37 TRAIN_LSTM.py
# -rw-r--r-- 1 root root  8974 Feb 26 12:37 TRAIN_RNN.py
# -rw-r--r-- 1 root root  3247 Feb 26 12:37 USE_THE_SAVED_FINE_TUNED_MODEL_CODE.py
# drwxr-xr-x 2 root root  4096 Feb 26 12:37 Images
# -rw-r--r-- 1 root root  5399 Feb 26 12:37 GRAD-CAM.py
# ...

# %%
# !pip install lime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=8bc11be69b64820fa8bc1c5390f51b8a0eb78c2b82e4a60b0fdb708fdf551c6d
#   Stored in directory: /root/.cache/pip/wheels/85/fa/a3/9c2d44c9f3cd77cf4e533b58900b2bf4487f2a17e8ec212a3d
# Successfully built lime
# ...

# %%
# !python LIME.py
# Out:
# 2025-02-26 14:42:30.055775: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740580950.073440   31693 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740580950.078416   31693 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-26 14:42:30.098947: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
